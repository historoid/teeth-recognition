# %%
import pathlib
import os
import pprint
import glob
import re
import shutil
import random

# %%
shutil.copyfile('../img/FD512ULG-11,12,13,14,22,23,25,27,31,41,46,47.png', './train/001.png')
# Out:
# './train/001.png'

# %%
pickup = list(origin_dir.glob('F*ULG*12*15*26*33*45*png'))
len(pickup)
# Out:
# 201

# %%
f = list(origin_dir.glob('F512*.png'))
fu = list(origin_dir.glob('FU512*.png'))
l = list(origin_dir.glob('L512*.png'))
l2 = list(origin_dir.glob('L2512*.png'))
ld = list(origin_dir.glob('LD512*.png'))
ld2 = list(origin_dir.glob('LD2512*.png'))
lu = list(origin_dir.glob('LU512*.png'))
lu2 = list(origin_dir.glob('LU2512*.png'))
r = list(origin_dir.glob('R512*.png'))
r2 = list(origin_dir.glob('R2512*.png'))
rd = list(origin_dir.glob('RD512*.png'))
rd2 = list(origin_dir.glob('RD2512*.png'))
ru = list(origin_dir.glob('RU512*.png'))
ru2 = list(origin_dir.glob('RU2512*.png'))

# %%
random.seed(0)
print(random.choice(f))
random.seed(0)
print(random.choice(f))
# Out:
# ../img/F512ULG-12,13,14,17,21,22,23,25,27,31,33,34,36,42,44,45.png
# ../img/F512ULG-12,13,14,17,21,22,23,25,27,31,33,34,36,42,44,45.png

# %%
origin_dir = pathlib.Path('./origin')
f = list(origin_dir.glob('F512*.png'))
fu = list(origin_dir.glob('FU512*.png'))
l = list(origin_dir.glob('L512*.png'))
l2 = list(origin_dir.glob('L2512*.png'))
ld = list(origin_dir.glob('LD512*.png'))
ld2 = list(origin_dir.glob('LD2512*.png'))
lu = list(origin_dir.glob('LU512*.png'))
lu2 = list(origin_dir.glob('LU2512*.png'))
r = list(origin_dir.glob('R512*.png'))
r2 = list(origin_dir.glob('R2512*.png'))
rd = list(origin_dir.glob('RD512*.png'))
rd2 = list(origin_dir.glob('RD2512*.png'))
ru = list(origin_dir.glob('RU512*.png'))
ru2 = list(origin_dir.glob('RU2512*.png'))

# %%
for camera_angle in [f, fu, l, l2, ld, ld2, lu, lu2, r, r2, rd, rd2, ru, ru2]:
    random.seed(0)
    pictures = random.sample(camera_angle, 10)
    for file in pictures:
        shutil.move(str(file), './test')

# %%
train_img_dir = pathlib.Path('./train')
for file_path in list(train_img_dir.glob('*.png')):
    print(str(file_path))
# Out:
# train/LU512ULG-11,12,13,14,15,17,21,22,23,24,25,26,27,31,33,34,36,37,41,42,43,44,45,46,47.png
# train/LD512ULG-34,41,43.png
# train/RU512ULG-33,41.png
# train/R512ULG-11,12,13,15,17,22,23,24,26,27,31,32,33,34,35,36,37,41,42,43,44,45.png
# train/L2512ULG-11,13,15,16,17,21,22,25,26,27,31,32,33,34,36,37,42,43,44,46,47.png
# train/F512ULG-11,12,13,21,34,36,46,47.png
# train/RD2512ULG-13,14,22,24,25,27,35,36,43,44.png
# train/R2512ULG-22,41,43.png
# train/LU512ULG-13,14,16,17,21,22,23,25,26,27,31,36,41,43,45,46,47.png
# train/RU2512ULG-12,13,14,16,23,24,25,26,27,31,33,37,41,42,44,46,47.png
# train/R512ULG-11,12,13,15,16,22,24,33,34,36,37,41,42,47.png
# train/L512ULG-15,25,26,37,41.png
# train/L2512ULG-13,22,26,33,35,37,42,43,44,47.png
# train/LD512ULG-11,13,14,15,16,17,21,22,23,24,25,26,27,31,32,33,34,35,36,37,41,42,43,44,45,46,47.png
# train/FU512ULG-11,12,15,16,17,21,22,24,25,31,32,37,41,43,44,47.png
# train/RD2512ULG-11,14,17,21,22,24,25,26,27,32,36,42,43,44,45,47.png
# ...

# %%
test_img_dir = pathlib.Path('./test')
for file_path in list(test_img_dir.glob('*.png')):
    print(str(file_path))
# Out:
# test/LU512ULG-11,12,14,15,16,17,21,24,25,26,27,31,32,33,36,37,41,42,45,46,47.png
# test/L2512ULG-11,14,15,16,17,21,22,23,24,26,31,32,35,41,43,44.png
# test/RU512ULG-11,12,14,15,16,17,21,23,24,26,27,31,32,33,34,35,36,37,41,42,44,45,46,47.png
# test/RU2512ULG-16,21,24,42,47.png
# test/LD512ULG-11,12,13,14,16,21,22,23,24,25,26,27,31,32,33,34,35,36,37,42,43,44,45,46,47.png
# test/F512ULG-11,13,16,17,21,22,23,26,27,31,32,33,34,36,37,41,42,44,45,46,47.png
# test/LU2512ULG-11,12,13,14,15,16,17,21,22,23,24,25,26,27,31,32,33,34,36,37,41,42,43,44,46,47.png
# test/FU512ULG-16,17,25,26,46.png
# test/LD2512ULG-15,22,23,25,35,37.png
# test/R512ULG-14,15,16,17,22,23,25,26,27,33,35,36,37,41,42,43,44,46,47.png
# test/RD2512ULG-12,13,14,16,17,22,25,27,31,32,33,36,42,43,44.png
# test/RD512ULG-13,16,17,22,24,43.png
# test/L512ULG-11,12,17,21,23,24,25,26,27,32,33,34,35,37,41,42.png
# test/R2512ULG-11,12,13,14,15,16,17,22,23,24,26,27,31,34,35,36,41,43,45,46,47.png
# test/LU512ULG-12,26,36.png
# ...
